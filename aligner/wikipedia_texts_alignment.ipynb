# %%
# !pip install razdel
# Out:
# Collecting razdel
#   Downloading razdel-0.5.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Installing collected packages: razdel
# Successfully installed razdel-0.5.0

# %%
import json

import pandas as pd
from transformers import BertModel, BertTokenizerFast

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls drive/MyDrive/diploma/data
# Out:
# aligned_chekhov_75.000_sents_09_02.json
# aligned_chekhov_chameleon_sents_09_02.json
# aligned_chekhov_maria_ivanovna_sents_09_02.json
# aligned_chekhov_person_in_case_sents_09_02.json
# aligned_chekhov_prishibaev_sents_09_02.json
# aligned_chekhov_self-delusion_sents_09_02.json
# aligned_chekhov_trifon_sents_09_02.json
# aligned_furmanov_chapaev_sents_09_02.json
# aligned_gaydar_distant_countries_sents_09_02.json
# aligned_gogol_dead_souls_sample_sents_09_02.json
# aligned_gorkiy_happiness_sents_09_02.json
# aligned_gorkiy_hero_sents_09_02.json
# aligned_gorkiy_italian_11_sents_09_02.json
# aligned_gorkiy_mother_part2_sents_09_02.json
# aligned_gorkiy_mother_sents_09_02.json
# aligned_gorkiy_russian_fairy_tales_sents_09_02.json
# aligned_konstitution_sents_09_02.json
# aligned_land_direct_sents_09_02.json
# aligned_news_names_09_02.json
# aligned_news_sents_09_02.json
# aligned_shchedrin_konyaga_sents_09_02.json
# aligned_shchedrin_vilage_fire_sents_09_02.json
# all_dicts_data.tsv
# all_phrases.tsv
# e-mordovia
# mdf_mono
# moksha_bible.tsv
# moksha_pravda.tsv
# texts_for_align
# train_test_splitting

# %%
from itertools import groupby
import re

import razdel

QUOTE_TYPE = '"'
DASH_TYPE = '-'


def remove_hyphenation(text: str) -> str:
    """
    Removes hyphenation from a given text by merging words split with hyphens or spaces.

    Example:
        "по-\ нимаемый иска- женный при- мер" -> "понимаемый искаженный пример"

    Args:
        text (str): The input text containing hyphenated words.

    Returns:
        str: The text with hyphenation removed.
    """
    return re.sub(
        rf'(\w)([\{DASH_TYPE}+]\s+)(\w)',
        lambda matchobj: matchobj.group(1) + matchobj.group(3),
        text
    )


def limit_repeated_chars(text: str, max_run: int = 3) -> str:
    """
    Limits consecutive repeated characters to a specified maximum number.

    Example:
        "[8_________________________ 2400 3 сядт, 4 дес. 6 един." -> "[8___ 2400 3 сядт, 4 дес. 6 един."

    Args:
        text (str): The input text containing repeated characters.
        max_run (int, optional): The maximum number of consecutive identical characters allowed. Default is 3.

    Returns:
        str: The text with excessive repeated characters trimmed.
    """
    return ''.join(''.join(list(group)[:max_run]) for _, group in groupby(text))


def clean_text(raw_text: str) -> str:
    """
    Cleans the input text by performing the following operations:
    - Replacing all quotes with the specified type.
    - Replacing all dashes with the specified type.
    - Removing hyphenation.
    - Limiting repeated characters.
    - Replacing multiple spaces with a single space.
    - Removing asterisks at the beginning of words.
    - Normalizing spacing around periods.

    Args:
        raw_text (str): The input raw text.

    Returns:
        str: The cleaned text.
    """
    text = re.sub(r'[“”„‟«»‘’‚‛]', QUOTE_TYPE, raw_text)
#     text = re.sub(r'[‐‑‒–—―]', DASH_TYPE, text)

    text = remove_hyphenation(text)
    text = limit_repeated_chars(text)

    text = re.sub('(\. )+', '. ', text)
    text = text.replace('\xa0', ' ')

    text = re.sub('\s+', ' ', text)

    text = text.replace('* ', '')
    return text.strip()


def split_into_sentences(text: str) -> list[str]:
    """
    Splits a given text into sentences using the Razdel library.

    Args:
        text (str): The input text to be split.

    Returns:
        list[str]: A list of sentences extracted from the text.
    """
    sents = []
    for sent in razdel.sentenize(text):
        sent_text = sent.text.replace('-\n', '').replace('\n', ' ').strip()
        sents.append(sent_text)
    return sents


def is_text_valid(text: str) -> bool:
    """
    Checks if the given text meets validity criteria:
    - Contains at least one word with two or more characters.
    - Contains at least one Cyrillic letter.
    - Has a length between 3 and 500 characters.

    Args:
        text (str): The input text to validate.

    Returns:
        bool: True if the text is valid, False otherwise.
    """
    if max(len(w) for w in text.split()) < 2:
        return False

    if not re.match('.*[а-яё].*', text.lower()):
        return False

    if len(text) < 3:
        return False

    if len(text) > 500:
        return False

    return True

# %%
import numpy as np
import torch
from transformers import BertModel, BertTokenizerFast


def align_sentences(
        lang1_text: str,
        lang2_text: str,
        model: BertModel,
        tokenizer: BertTokenizerFast,
        alpha: float = 0.2,
        penalty: float = 0.2,
        threshold: float = 0.45,
    ) -> list[list[str]]:
    """
    Aligns sentences between two languages using sentence embeddings and similarity metrics.

    Args:
        lang1_text (str): The text in the first language.
        lang2_text (str): The text in the second language.
        model (BertModel): The embedding model.
        tokenizer (BertTokenizerFast): The tokenizer for the model.
        alpha (float, optional): The alpha parameter for similarity adjustment. Default is 0.2.
        penalty (float, optional): The penalty for alignment. Default is 0.2.
        threshold (float, optional): The similarity threshold for alignment. Default is 0.45.

    Returns:
        list[list[str]]: A list of aligned sentence pairs.
    """
    cleaned_lang1_text = clean_text(lang1_text)
    cleaned_lang2_text = clean_text(lang2_text)

    sents_lang1 = split_into_sentences(cleaned_lang1_text)
    sents_lang2 = split_into_sentences(cleaned_lang2_text)

    if not sents_lang1 and not sents_lang2:
        return []

    emb_lang1 = np.stack([get_sentence_embedding(s, model, tokenizer) for s in sents_lang1])
    emb_lang2 = np.stack([get_sentence_embedding(s, model, tokenizer) for s in sents_lang2])

    length_ratio = np.array([[min(len(x), len(y)) / max(len(x), len(y)) for x in sents_lang2] for y in sents_lang1])
    sims = np.maximum(0, np.dot(emb_lang1, emb_lang2.T)) ** 1 * length_ratio

    sims_rel = (sims.T - compute_topk_mean(sims) * alpha).T - compute_topk_mean(sims.T) * alpha - penalty

    alignment = compute_alignment_path(sims_rel)

    aligned_pairs = []
    for i, j in alignment:
        if sims[i, j] >= threshold:
            aligned_pairs.append([sents_lang1[i], sents_lang2[j]])

    return aligned_pairs


def get_sentence_embedding(text: str, model: BertModel, tokenizer: BertTokenizerFast, max_length: int = 128) -> np.ndarray:
    """
    Computes the sentence embedding using a transformer model.

    Args:
        text (str): The input text.
        model (BertModel): The embedding model.
        tokenizer (BertTokenizerFast): The tokenizer for the model.
        max_length (int, optional): The maximum token length. Default is 128.

    Returns:
        np.ndarray: The sentence embedding vector.
    """
    encoded_input = tokenizer(
        text,
        padding=True,
        truncation=True,
        max_length=max_length,
        return_tensors='pt'
    ).to(model.device)

    with torch.inference_mode():
        model_output = model(**encoded_input)
    embeddings = torch.nn.functional.normalize(model_output.pooler_output)

    return embeddings[0].detach().cpu().numpy()


def compute_topk_mean(x: np.ndarray, k: int = 5) -> np.ndarray:
    """
    Computes the mean of the top-k values in each row of a matrix.

    Args:
        x (np.ndarray): The input matrix.
        k (int, optional): The number of top elements to consider. Default is 5.

    Returns:
        np.ndarray: The mean values for each row.
    """
    m, n = x.shape
    k = min(k, n)
    topk_indices = np.argpartition(x, -k, axis=1)[:, -k:]
    rows, _ = np.indices((m, k))
    return x[rows, topk_indices].mean(1)


def compute_alignment_path(sims: np.ndarray) -> list[list[int]]:
    """
    Computes the optimal alignment path between two sets of sentences based on similarity scores.

    Args:
        sims (np.ndarray): The similarity matrix.

    Returns:
        list[list[int]]: A list of aligned index pairs.
    """
    rewards = np.zeros_like(sims)
    choices = np.zeros_like(sims, dtype=int)

    for i in range(sims.shape[0]):
        for j in range(0, sims.shape[1]):
            score_add = sims[i, j]
            if i > 0 and j > 0:
                score_add += rewards[i-1, j-1]
                choices[i, j] = 1
            best = score_add
            if i > 0 and rewards[i-1, j] > best:
                best = rewards[i-1, j]
                choices[i, j] = 2
            if j > 0 and rewards[i, j-1] > best:
                best = rewards[i, j-1]
                choices[i, j] = 3
            rewards[i, j] = best

    alignment = []
    i = sims.shape[0] - 1
    j = sims.shape[1] - 1
    while i > 0 and j > 0:
        if choices[i, j] == 1:
            alignment.append([i, j])
            i -= 1
            j -= 1
        elif choices[i, j] == 2:
            i -= 1
        else:
            j -= 1

    alignment.reverse()
    return alignment

# %%
DATA_PATH_PREFIX = 'drive/MyDrive/diploma/data/'

# %%
MODEL_PATH = 'drive/MyDrive/diploma/labse_moksha_40k+5k'

# %% [markdown]
# # Load df with parallel texts

# %%
wikipedia_texts = pd.read_pickle(DATA_PATH_PREFIX + 'texts_for_align/wikipedia_dump.pkl')

# %%
wikipedia_texts.shape
# Out:
# (3164, 2)

# %%
wikipedia_texts.head()
# Out:
#                                              ru_text  \
# 0  Раде́хов (укр. Раде́хів) — город в Червоноград...
# 1  Эпидендрум (лат. Epidendrum) — род многолетних...
# 2  Соломо́н Кверкве́лия (груз. სოლომონ კვირკველია...
# 3  Донгхой — город провинциального подчинения во ...
# 4  Старая Муравьёвка — опустевшая деревня в соста...
#
#                                             mdf_text
# 0  Радэхив (укр.: Радехів (няйф)) — ошсь Украинас...
# 1  Эпидендрум ( лат.: Epidendrum) — Орхидея тънал...
# 2  Соломон Квэрквэлия (груз.: სოლომონ კვირკველია;...
# 3  Донгхой (виет.: Đồng Hới) - ошсь Виетнамса, Ку...
# 4  Сире Муравьевка (руз.: Старая Муравьёвка) — мо...

# %% [markdown]
# # Align each article

# %%
model = BertModel.from_pretrained(MODEL_PATH)
tokenizer = BertTokenizerFast.from_pretrained(MODEL_PATH)

# %%
model.cuda();

# %%
all_aligned_pairs = []

for idx, (mdf_text, ru_text) in enumerate(zip(
    wikipedia_texts['mdf_text'],
    wikipedia_texts['ru_text']
)):
    if not ru_text or not mdf_text:
        print(f"empty pair: ({idx}), {mdf_text}, {ru_text}")
        continue

    aligned_pairs = align_sentences(mdf_text, ru_text, model, tokenizer)
    all_aligned_pairs += aligned_pairs

    if not aligned_pairs:
        print(f"0 aligned pairs: {idx}")
# Out:
# 0 aligned pairs: 0
# 0 aligned pairs: 1
# 0 aligned pairs: 3
# 0 aligned pairs: 4
# 0 aligned pairs: 5
# 0 aligned pairs: 6
# 0 aligned pairs: 7
# 0 aligned pairs: 9
# 0 aligned pairs: 11
# 0 aligned pairs: 14
# 0 aligned pairs: 15
# 0 aligned pairs: 16
# 0 aligned pairs: 18
# 0 aligned pairs: 20
# 0 aligned pairs: 21
# 0 aligned pairs: 23
# 0 aligned pairs: 24
# 0 aligned pairs: 25
# 0 aligned pairs: 26
# 0 aligned pairs: 28
# 0 aligned pairs: 29
# 0 aligned pairs: 30
# 0 aligned pairs: 34
# 0 aligned pairs: 36
# 0 aligned pairs: 38
# 0 aligned pairs: 39
# 0 aligned pairs: 40
# 0 aligned pairs: 41
# 0 aligned pairs: 42
# 0 aligned pairs: 44
# 0 aligned pairs: 45
# 0 aligned pairs: 48
# 0 aligned pairs: 49
# 0 aligned pairs: 50
# 0 aligned pairs: 53
# 0 aligned pairs: 54
# 0 aligned pairs: 55
# 0 aligned pairs: 56
# 0 aligned pairs: 57
# 0 aligned pairs: 59
# 0 aligned pairs: 61
# 0 aligned pairs: 62
# 0 aligned pairs: 63
# 0 aligned pairs: 64
# 0 aligned pairs: 65
# 0 aligned pairs: 66
# 0 aligned pairs: 67
# 0 aligned pairs: 68
# 0 aligned pairs: 70
# 0 aligned pairs: 72
# 0 aligned pairs: 73
# 0 aligned pairs: 74
# 0 aligned pairs: 75
# 0 aligned pairs: 77
# 0 aligned pairs: 78
# 0 aligned pairs: 79
# 0 aligned pairs: 80
# 0 aligned pairs: 81
# 0 aligned pairs: 82
# 0 aligned pairs: 83
# 0 aligned pairs: 85
# 0 aligned pairs: 86
# 0 aligned pairs: 88
# 0 aligned pairs: 89
# 0 aligned pairs: 90
# 0 aligned pairs: 91
# 0 aligned pairs: 92
# 0 aligned pairs: 94
# 0 aligned pairs: 95
# 0 aligned pairs: 96
# 0 aligned pairs: 97
# 0 aligned pairs: 98
# 0 aligned pairs: 99
# 0 aligned pairs: 101
# 0 aligned pairs: 104
# 0 aligned pairs: 106
# 0 aligned pairs: 107
# 0 aligned pairs: 108
# 0 aligned pairs: 111
# 0 aligned pairs: 112
# 0 aligned pairs: 113
# 0 aligned pairs: 114
# 0 aligned pairs: 117
# 0 aligned pairs: 118
# 0 aligned pairs: 119
# 0 aligned pairs: 121
# 0 aligned pairs: 122
# 0 aligned pairs: 123
# 0 aligned pairs: 124
# 0 aligned pairs: 125
# 0 aligned pairs: 126
# 0 aligned pairs: 127
# 0 aligned pairs: 128
# 0 aligned pairs: 130
# 0 aligned pairs: 132
# 0 aligned pairs: 133
# 0 aligned pairs: 134
# 0 aligned pairs: 135
# 0 aligned pairs: 137
# 0 aligned pairs: 139
# 0 aligned pairs: 140
# 0 aligned pairs: 141
# 0 aligned pairs: 142
# 0 aligned pairs: 143
# 0 aligned pairs: 144
# 0 aligned pairs: 145
# 0 aligned pairs: 146
# 0 aligned pairs: 148
# 0 aligned pairs: 149
# 0 aligned pairs: 150
# 0 aligned pairs: 154
# 0 aligned pairs: 156
# 0 aligned pairs: 157
# 0 aligned pairs: 158
# 0 aligned pairs: 159
# 0 aligned pairs: 164
# 0 aligned pairs: 165
# 0 aligned pairs: 166
# 0 aligned pairs: 168
# 0 aligned pairs: 169
# 0 aligned pairs: 171
# 0 aligned pairs: 173
# 0 aligned pairs: 174
# 0 aligned pairs: 175
# 0 aligned pairs: 176
# 0 aligned pairs: 178
# 0 aligned pairs: 179
# 0 aligned pairs: 180
# 0 aligned pairs: 181
# 0 aligned pairs: 183
# 0 aligned pairs: 186
# 0 aligned pairs: 187
# 0 aligned pairs: 188
# 0 aligned pairs: 189
# 0 aligned pairs: 190
# 0 aligned pairs: 193
# 0 aligned pairs: 194
# 0 aligned pairs: 195
# 0 aligned pairs: 196
# 0 aligned pairs: 197
# 0 aligned pairs: 198
# 0 aligned pairs: 199
# 0 aligned pairs: 200
# 0 aligned pairs: 201
# 0 aligned pairs: 202
# 0 aligned pairs: 203
# 0 aligned pairs: 204
# 0 aligned pairs: 206
# 0 aligned pairs: 207
# 0 aligned pairs: 208
# 0 aligned pairs: 209
# 0 aligned pairs: 210
# 0 aligned pairs: 211
# 0 aligned pairs: 212
# 0 aligned pairs: 213
# 0 aligned pairs: 214
# 0 aligned pairs: 215
# 0 aligned pairs: 216
# 0 aligned pairs: 220
# 0 aligned pairs: 222
# 0 aligned pairs: 223
# 0 aligned pairs: 224
# 0 aligned pairs: 225
# 0 aligned pairs: 226
# 0 aligned pairs: 227
# 0 aligned pairs: 228
# 0 aligned pairs: 229
# 0 aligned pairs: 231
# 0 aligned pairs: 232
# 0 aligned pairs: 233
# 0 aligned pairs: 234
# 0 aligned pairs: 235
# 0 aligned pairs: 236
# 0 aligned pairs: 238
# 0 aligned pairs: 239
# 0 aligned pairs: 240
# 0 aligned pairs: 241
# 0 aligned pairs: 242
# 0 aligned pairs: 243
# 0 aligned pairs: 245
# 0 aligned pairs: 246
# 0 aligned pairs: 247
# 0 aligned pairs: 248
# 0 aligned pairs: 249
# 0 aligned pairs: 253
# 0 aligned pairs: 254
# 0 aligned pairs: 256
# 0 aligned pairs: 258
# 0 aligned pairs: 259
# 0 aligned pairs: 260
# 0 aligned pairs: 261
# 0 aligned pairs: 263
# 0 aligned pairs: 264
# 0 aligned pairs: 265
# 0 aligned pairs: 266
# 0 aligned pairs: 267
# 0 aligned pairs: 268
# 0 aligned pairs: 269
# 0 aligned pairs: 270
# 0 aligned pairs: 272
# 0 aligned pairs: 273
# 0 aligned pairs: 274
# 0 aligned pairs: 275
# 0 aligned pairs: 276
# 0 aligned pairs: 278
# 0 aligned pairs: 280
# 0 aligned pairs: 281
# 0 aligned pairs: 283
# 0 aligned pairs: 284
# 0 aligned pairs: 285
# 0 aligned pairs: 287
# 0 aligned pairs: 288
# 0 aligned pairs: 289
# 0 aligned pairs: 290
# 0 aligned pairs: 291
# 0 aligned pairs: 293
# 0 aligned pairs: 294
# 0 aligned pairs: 295
# 0 aligned pairs: 296
# 0 aligned pairs: 297
# 0 aligned pairs: 299
# 0 aligned pairs: 300
# 0 aligned pairs: 301
# 0 aligned pairs: 302
# 0 aligned pairs: 303
# 0 aligned pairs: 304
# 0 aligned pairs: 305
# 0 aligned pairs: 307
# 0 aligned pairs: 308
# 0 aligned pairs: 309
# 0 aligned pairs: 313
# 0 aligned pairs: 314
# 0 aligned pairs: 315
# 0 aligned pairs: 317
# 0 aligned pairs: 320
# 0 aligned pairs: 321
# 0 aligned pairs: 324
# 0 aligned pairs: 325
# 0 aligned pairs: 326
# 0 aligned pairs: 327
# 0 aligned pairs: 328
# 0 aligned pairs: 329
# 0 aligned pairs: 330
# 0 aligned pairs: 331
# 0 aligned pairs: 332
# 0 aligned pairs: 333
# 0 aligned pairs: 335
# 0 aligned pairs: 336
# 0 aligned pairs: 337
# 0 aligned pairs: 338
# 0 aligned pairs: 339
# 0 aligned pairs: 340
# 0 aligned pairs: 342
# 0 aligned pairs: 343
# 0 aligned pairs: 346
# 0 aligned pairs: 348
# 0 aligned pairs: 349
# 0 aligned pairs: 350
# 0 aligned pairs: 351
# 0 aligned pairs: 352
# 0 aligned pairs: 353
# 0 aligned pairs: 354
# 0 aligned pairs: 355
# 0 aligned pairs: 360
# 0 aligned pairs: 361
# 0 aligned pairs: 362
# 0 aligned pairs: 363
# 0 aligned pairs: 364
# 0 aligned pairs: 365
# 0 aligned pairs: 366
# 0 aligned pairs: 367
# 0 aligned pairs: 368
# 0 aligned pairs: 370
# 0 aligned pairs: 372
# 0 aligned pairs: 373
# 0 aligned pairs: 374
# 0 aligned pairs: 375
# 0 aligned pairs: 376
# 0 aligned pairs: 378
# 0 aligned pairs: 379
# 0 aligned pairs: 380
# 0 aligned pairs: 381
# 0 aligned pairs: 382
# 0 aligned pairs: 383
# 0 aligned pairs: 384
# 0 aligned pairs: 385
# 0 aligned pairs: 386
# 0 aligned pairs: 387
# 0 aligned pairs: 388
# 0 aligned pairs: 389
# 0 aligned pairs: 390
# 0 aligned pairs: 391
# 0 aligned pairs: 392
# 0 aligned pairs: 393
# 0 aligned pairs: 395
# 0 aligned pairs: 397
# 0 aligned pairs: 398
# 0 aligned pairs: 399
# 0 aligned pairs: 400
# 0 aligned pairs: 401
# 0 aligned pairs: 402
# 0 aligned pairs: 406
# 0 aligned pairs: 407
# 0 aligned pairs: 408
# 0 aligned pairs: 409
# 0 aligned pairs: 410
# 0 aligned pairs: 411
# 0 aligned pairs: 412
# 0 aligned pairs: 413
# 0 aligned pairs: 414
# 0 aligned pairs: 415
# 0 aligned pairs: 418
# 0 aligned pairs: 419
# 0 aligned pairs: 420
# 0 aligned pairs: 421
# 0 aligned pairs: 422
# 0 aligned pairs: 424
# 0 aligned pairs: 425
# 0 aligned pairs: 426
# 0 aligned pairs: 427
# 0 aligned pairs: 428
# 0 aligned pairs: 430
# 0 aligned pairs: 431
# 0 aligned pairs: 432
# 0 aligned pairs: 433
# 0 aligned pairs: 434
# 0 aligned pairs: 435
# 0 aligned pairs: 436
# 0 aligned pairs: 437
# 0 aligned pairs: 438
# 0 aligned pairs: 439
# 0 aligned pairs: 441
# 0 aligned pairs: 443
# 0 aligned pairs: 444
# 0 aligned pairs: 446
# 0 aligned pairs: 447
# 0 aligned pairs: 448
# 0 aligned pairs: 449
# 0 aligned pairs: 451
# 0 aligned pairs: 452
# 0 aligned pairs: 453
# 0 aligned pairs: 454
# 0 aligned pairs: 455
# 0 aligned pairs: 456
# 0 aligned pairs: 457
# 0 aligned pairs: 458
# 0 aligned pairs: 460
# 0 aligned pairs: 462
# 0 aligned pairs: 463
# 0 aligned pairs: 464
# 0 aligned pairs: 465
# 0 aligned pairs: 466
# 0 aligned pairs: 467
# 0 aligned pairs: 468
# 0 aligned pairs: 469
# 0 aligned pairs: 470
# 0 aligned pairs: 472
# 0 aligned pairs: 473
# 0 aligned pairs: 475
# 0 aligned pairs: 476
# 0 aligned pairs: 479
# 0 aligned pairs: 480
# 0 aligned pairs: 481
# 0 aligned pairs: 483
# 0 aligned pairs: 484
# 0 aligned pairs: 486
# 0 aligned pairs: 488
# 0 aligned pairs: 490
# 0 aligned pairs: 492
# 0 aligned pairs: 494
# 0 aligned pairs: 495
# 0 aligned pairs: 499
# 0 aligned pairs: 500
# 0 aligned pairs: 502
# 0 aligned pairs: 503
# 0 aligned pairs: 504
# 0 aligned pairs: 505
# 0 aligned pairs: 506
# 0 aligned pairs: 507
# 0 aligned pairs: 508
# 0 aligned pairs: 510
# 0 aligned pairs: 511
# 0 aligned pairs: 512
# 0 aligned pairs: 513
# 0 aligned pairs: 514
# 0 aligned pairs: 515
# 0 aligned pairs: 517
# 0 aligned pairs: 518
# 0 aligned pairs: 519
# 0 aligned pairs: 520
# 0 aligned pairs: 521
# 0 aligned pairs: 522
# 0 aligned pairs: 523
# 0 aligned pairs: 524
# 0 aligned pairs: 525
# 0 aligned pairs: 527
# 0 aligned pairs: 528
# 0 aligned pairs: 529
# 0 aligned pairs: 531
# 0 aligned pairs: 532
# 0 aligned pairs: 533
# 0 aligned pairs: 534
# 0 aligned pairs: 535
# 0 aligned pairs: 536
# 0 aligned pairs: 537
# 0 aligned pairs: 538
# 0 aligned pairs: 540
# 0 aligned pairs: 541
# 0 aligned pairs: 542
# 0 aligned pairs: 544
# 0 aligned pairs: 545
# 0 aligned pairs: 546
# 0 aligned pairs: 547
# 0 aligned pairs: 548
# 0 aligned pairs: 549
# 0 aligned pairs: 550
# 0 aligned pairs: 551
# 0 aligned pairs: 552
# 0 aligned pairs: 553
# 0 aligned pairs: 554
# 0 aligned pairs: 557
# 0 aligned pairs: 559
# 0 aligned pairs: 560
# 0 aligned pairs: 562
# 0 aligned pairs: 563
# 0 aligned pairs: 565
# 0 aligned pairs: 566
# 0 aligned pairs: 568
# 0 aligned pairs: 569
# 0 aligned pairs: 570
# 0 aligned pairs: 571
# 0 aligned pairs: 572
# 0 aligned pairs: 574
# 0 aligned pairs: 576
# 0 aligned pairs: 577
# 0 aligned pairs: 578
# 0 aligned pairs: 579
# 0 aligned pairs: 580
# 0 aligned pairs: 581
# 0 aligned pairs: 582
# 0 aligned pairs: 583
# 0 aligned pairs: 587
# 0 aligned pairs: 588
# 0 aligned pairs: 589
# 0 aligned pairs: 590
# 0 aligned pairs: 591
# 0 aligned pairs: 592
# 0 aligned pairs: 593
# 0 aligned pairs: 594
# 0 aligned pairs: 596
# 0 aligned pairs: 598
# 0 aligned pairs: 601
# 0 aligned pairs: 602
# 0 aligned pairs: 603
# 0 aligned pairs: 605
# 0 aligned pairs: 606
# 0 aligned pairs: 607
# 0 aligned pairs: 608
# 0 aligned pairs: 609
# 0 aligned pairs: 610
# 0 aligned pairs: 611
# 0 aligned pairs: 612
# 0 aligned pairs: 613
# 0 aligned pairs: 614
# 0 aligned pairs: 615
# 0 aligned pairs: 616
# 0 aligned pairs: 618
# 0 aligned pairs: 619
# 0 aligned pairs: 621
# 0 aligned pairs: 622
# 0 aligned pairs: 624
# 0 aligned pairs: 625
# 0 aligned pairs: 626
# 0 aligned pairs: 627
# 0 aligned pairs: 630
# 0 aligned pairs: 631
# 0 aligned pairs: 632
# 0 aligned pairs: 634
# 0 aligned pairs: 635
# 0 aligned pairs: 636
# 0 aligned pairs: 638
# 0 aligned pairs: 639
# 0 aligned pairs: 641
# 0 aligned pairs: 642
# 0 aligned pairs: 643
# 0 aligned pairs: 644
# 0 aligned pairs: 651
# 0 aligned pairs: 652
# 0 aligned pairs: 653
# 0 aligned pairs: 654
# 0 aligned pairs: 658
# 0 aligned pairs: 659
# 0 aligned pairs: 660
# 0 aligned pairs: 661
# 0 aligned pairs: 664
# 0 aligned pairs: 665
# 0 aligned pairs: 668
# 0 aligned pairs: 670
# 0 aligned pairs: 671
# 0 aligned pairs: 672
# 0 aligned pairs: 673
# 0 aligned pairs: 674
# 0 aligned pairs: 675
# 0 aligned pairs: 678
# 0 aligned pairs: 680
# 0 aligned pairs: 681
# 0 aligned pairs: 682
# 0 aligned pairs: 684
# 0 aligned pairs: 685
# 0 aligned pairs: 686
# 0 aligned pairs: 688
# 0 aligned pairs: 691
# 0 aligned pairs: 694
# 0 aligned pairs: 696
# 0 aligned pairs: 698
# 0 aligned pairs: 699
# 0 aligned pairs: 701
# 0 aligned pairs: 702
# 0 aligned pairs: 703
# 0 aligned pairs: 704
# 0 aligned pairs: 705
# 0 aligned pairs: 706
# 0 aligned pairs: 707
# 0 aligned pairs: 708
# 0 aligned pairs: 710
# 0 aligned pairs: 711
# 0 aligned pairs: 713
# 0 aligned pairs: 714
# 0 aligned pairs: 716
# 0 aligned pairs: 717
# 0 aligned pairs: 720
# 0 aligned pairs: 721
# 0 aligned pairs: 723
# 0 aligned pairs: 724
# 0 aligned pairs: 725
# 0 aligned pairs: 726
# 0 aligned pairs: 728
# 0 aligned pairs: 729
# 0 aligned pairs: 730
# 0 aligned pairs: 731
# 0 aligned pairs: 732
# 0 aligned pairs: 733
# 0 aligned pairs: 735
# 0 aligned pairs: 736
# 0 aligned pairs: 737
# 0 aligned pairs: 738
# 0 aligned pairs: 739
# 0 aligned pairs: 740
# 0 aligned pairs: 742
# 0 aligned pairs: 743
# 0 aligned pairs: 744
# 0 aligned pairs: 746
# 0 aligned pairs: 747
# 0 aligned pairs: 748
# 0 aligned pairs: 749
# 0 aligned pairs: 752
# 0 aligned pairs: 754
# 0 aligned pairs: 756
# 0 aligned pairs: 757
# 0 aligned pairs: 760
# 0 aligned pairs: 761
# 0 aligned pairs: 763
# 0 aligned pairs: 765
# 0 aligned pairs: 767
# 0 aligned pairs: 768
# 0 aligned pairs: 770
# 0 aligned pairs: 771
# 0 aligned pairs: 772
# 0 aligned pairs: 773
# 0 aligned pairs: 774
# 0 aligned pairs: 775
# 0 aligned pairs: 776
# 0 aligned pairs: 777
# 0 aligned pairs: 778
# 0 aligned pairs: 780
# 0 aligned pairs: 781
# 0 aligned pairs: 785
# 0 aligned pairs: 786
# 0 aligned pairs: 787
# 0 aligned pairs: 788
# 0 aligned pairs: 789
# 0 aligned pairs: 790
# 0 aligned pairs: 791
# 0 aligned pairs: 792
# 0 aligned pairs: 795
# 0 aligned pairs: 796
# 0 aligned pairs: 797
# 0 aligned pairs: 798
# 0 aligned pairs: 799
# 0 aligned pairs: 800
# 0 aligned pairs: 801
# 0 aligned pairs: 802
# 0 aligned pairs: 804
# 0 aligned pairs: 805
# 0 aligned pairs: 806
# 0 aligned pairs: 807
# 0 aligned pairs: 809
# 0 aligned pairs: 812
# 0 aligned pairs: 813
# 0 aligned pairs: 814
# 0 aligned pairs: 817
# 0 aligned pairs: 818
# 0 aligned pairs: 820
# 0 aligned pairs: 822
# 0 aligned pairs: 824
# 0 aligned pairs: 825
# 0 aligned pairs: 826
# 0 aligned pairs: 827
# 0 aligned pairs: 828
# 0 aligned pairs: 829
# 0 aligned pairs: 830
# 0 aligned pairs: 831
# 0 aligned pairs: 832
# 0 aligned pairs: 834
# 0 aligned pairs: 835
# 0 aligned pairs: 836
# 0 aligned pairs: 838
# 0 aligned pairs: 839
# 0 aligned pairs: 840
# 0 aligned pairs: 841
# 0 aligned pairs: 842
# 0 aligned pairs: 844
# 0 aligned pairs: 845
# 0 aligned pairs: 846
# 0 aligned pairs: 847
# 0 aligned pairs: 848
# 0 aligned pairs: 851
# 0 aligned pairs: 852
# 0 aligned pairs: 853
# 0 aligned pairs: 855
# 0 aligned pairs: 857
# 0 aligned pairs: 858
# 0 aligned pairs: 861
# 0 aligned pairs: 862
# 0 aligned pairs: 863
# 0 aligned pairs: 864
# 0 aligned pairs: 865
# 0 aligned pairs: 868
# 0 aligned pairs: 869
# 0 aligned pairs: 870
# 0 aligned pairs: 872
# 0 aligned pairs: 873
# 0 aligned pairs: 874
# 0 aligned pairs: 875
# 0 aligned pairs: 876
# 0 aligned pairs: 877
# 0 aligned pairs: 878
# 0 aligned pairs: 879
# 0 aligned pairs: 880
# 0 aligned pairs: 881
# 0 aligned pairs: 883
# 0 aligned pairs: 885
# 0 aligned pairs: 886
# 0 aligned pairs: 887
# 0 aligned pairs: 888
# 0 aligned pairs: 889
# 0 aligned pairs: 891
# 0 aligned pairs: 892
# 0 aligned pairs: 893
# 0 aligned pairs: 894
# 0 aligned pairs: 895
# 0 aligned pairs: 896
# 0 aligned pairs: 897
# 0 aligned pairs: 898
# 0 aligned pairs: 899
# 0 aligned pairs: 900
# 0 aligned pairs: 901
# 0 aligned pairs: 902
# 0 aligned pairs: 903
# 0 aligned pairs: 904
# 0 aligned pairs: 906
# 0 aligned pairs: 908
# 0 aligned pairs: 909
# 0 aligned pairs: 910
# 0 aligned pairs: 911
# 0 aligned pairs: 912
# 0 aligned pairs: 913
# 0 aligned pairs: 914
# 0 aligned pairs: 915
# 0 aligned pairs: 916
# 0 aligned pairs: 917
# 0 aligned pairs: 918
# 0 aligned pairs: 919
# 0 aligned pairs: 920
# 0 aligned pairs: 921
# 0 aligned pairs: 922
# 0 aligned pairs: 923
# 0 aligned pairs: 924
# 0 aligned pairs: 925
# 0 aligned pairs: 927
# 0 aligned pairs: 929
# 0 aligned pairs: 930
# 0 aligned pairs: 931
# 0 aligned pairs: 933
# 0 aligned pairs: 935
# 0 aligned pairs: 936
# 0 aligned pairs: 937
# 0 aligned pairs: 938
# 0 aligned pairs: 940
# 0 aligned pairs: 941
# 0 aligned pairs: 942
# 0 aligned pairs: 943
# 0 aligned pairs: 944
# 0 aligned pairs: 945
# 0 aligned pairs: 946
# 0 aligned pairs: 949
# 0 aligned pairs: 951
# 0 aligned pairs: 952
# 0 aligned pairs: 953
# 0 aligned pairs: 954
# 0 aligned pairs: 955
# 0 aligned pairs: 956
# 0 aligned pairs: 957
# 0 aligned pairs: 958
# 0 aligned pairs: 960
# 0 aligned pairs: 961
# 0 aligned pairs: 963
# 0 aligned pairs: 964
# 0 aligned pairs: 965
# 0 aligned pairs: 966
# 0 aligned pairs: 970
# 0 aligned pairs: 972
# 0 aligned pairs: 973
# 0 aligned pairs: 974
# 0 aligned pairs: 975
# 0 aligned pairs: 977
# 0 aligned pairs: 979
# 0 aligned pairs: 980
# 0 aligned pairs: 981
# 0 aligned pairs: 982
# 0 aligned pairs: 985
# 0 aligned pairs: 986
# 0 aligned pairs: 987
# 0 aligned pairs: 988
# 0 aligned pairs: 990
# 0 aligned pairs: 991
# 0 aligned pairs: 992
# 0 aligned pairs: 993
# 0 aligned pairs: 994
# 0 aligned pairs: 996
# 0 aligned pairs: 997
# 0 aligned pairs: 998
# 0 aligned pairs: 999
# 0 aligned pairs: 1001
# 0 aligned pairs: 1002
# 0 aligned pairs: 1003
# 0 aligned pairs: 1004
# 0 aligned pairs: 1005
# 0 aligned pairs: 1006
# 0 aligned pairs: 1008
# 0 aligned pairs: 1009
# 0 aligned pairs: 1010
# 0 aligned pairs: 1012
# 0 aligned pairs: 1013
# 0 aligned pairs: 1016
# 0 aligned pairs: 1017
# 0 aligned pairs: 1018
# 0 aligned pairs: 1019
# 0 aligned pairs: 1020
# 0 aligned pairs: 1021
# 0 aligned pairs: 1024
# 0 aligned pairs: 1025
# 0 aligned pairs: 1026
# 0 aligned pairs: 1028
# 0 aligned pairs: 1029
# 0 aligned pairs: 1030
# 0 aligned pairs: 1031
# 0 aligned pairs: 1033
# 0 aligned pairs: 1035
# 0 aligned pairs: 1036
# 0 aligned pairs: 1037
# 0 aligned pairs: 1038
# 0 aligned pairs: 1039
# 0 aligned pairs: 1040
# 0 aligned pairs: 1042
# 0 aligned pairs: 1044
# 0 aligned pairs: 1045
# 0 aligned pairs: 1046
# 0 aligned pairs: 1048
# 0 aligned pairs: 1050
# 0 aligned pairs: 1052
# 0 aligned pairs: 1053
# 0 aligned pairs: 1054
# 0 aligned pairs: 1055
# 0 aligned pairs: 1056
# 0 aligned pairs: 1057
# 0 aligned pairs: 1059
# 0 aligned pairs: 1060
# 0 aligned pairs: 1061
# 0 aligned pairs: 1063
# 0 aligned pairs: 1065
# 0 aligned pairs: 1067
# 0 aligned pairs: 1068
# 0 aligned pairs: 1069
# 0 aligned pairs: 1070
# 0 aligned pairs: 1071
# 0 aligned pairs: 1072
# 0 aligned pairs: 1073
# 0 aligned pairs: 1074
# 0 aligned pairs: 1075
# 0 aligned pairs: 1077
# 0 aligned pairs: 1079
# 0 aligned pairs: 1080
# 0 aligned pairs: 1081
# 0 aligned pairs: 1082
# 0 aligned pairs: 1083
# 0 aligned pairs: 1084
# 0 aligned pairs: 1085
# 0 aligned pairs: 1086
# 0 aligned pairs: 1087
# 0 aligned pairs: 1088
# 0 aligned pairs: 1089
# 0 aligned pairs: 1090
# 0 aligned pairs: 1091
# 0 aligned pairs: 1092
# 0 aligned pairs: 1093
# 0 aligned pairs: 1094
# 0 aligned pairs: 1095
# 0 aligned pairs: 1097
# 0 aligned pairs: 1098
# 0 aligned pairs: 1100
# 0 aligned pairs: 1101
# 0 aligned pairs: 1102
# 0 aligned pairs: 1103
# 0 aligned pairs: 1105
# 0 aligned pairs: 1107
# 0 aligned pairs: 1108
# 0 aligned pairs: 1109
# 0 aligned pairs: 1110
# 0 aligned pairs: 1112
# 0 aligned pairs: 1114
# 0 aligned pairs: 1115
# 0 aligned pairs: 1116
# 0 aligned pairs: 1118
# 0 aligned pairs: 1120
# 0 aligned pairs: 1121
# 0 aligned pairs: 1122
# 0 aligned pairs: 1123
# 0 aligned pairs: 1124
# 0 aligned pairs: 1125
# 0 aligned pairs: 1127
# 0 aligned pairs: 1128
# 0 aligned pairs: 1129
# 0 aligned pairs: 1130
# 0 aligned pairs: 1131
# 0 aligned pairs: 1132
# 0 aligned pairs: 1133
# 0 aligned pairs: 1134
# 0 aligned pairs: 1136
# 0 aligned pairs: 1137
# 0 aligned pairs: 1138
# 0 aligned pairs: 1139
# 0 aligned pairs: 1140
# 0 aligned pairs: 1141
# 0 aligned pairs: 1142
# 0 aligned pairs: 1143
# 0 aligned pairs: 1145
# 0 aligned pairs: 1147
# 0 aligned pairs: 1150
# 0 aligned pairs: 1151
# 0 aligned pairs: 1152
# 0 aligned pairs: 1153
# 0 aligned pairs: 1155
# 0 aligned pairs: 1156
# 0 aligned pairs: 1157
# 0 aligned pairs: 1158
# 0 aligned pairs: 1159
# 0 aligned pairs: 1160
# 0 aligned pairs: 1161
# 0 aligned pairs: 1162
# 0 aligned pairs: 1164
# 0 aligned pairs: 1165
# 0 aligned pairs: 1166
# 0 aligned pairs: 1167
# 0 aligned pairs: 1168
# 0 aligned pairs: 1171
# 0 aligned pairs: 1172
# 0 aligned pairs: 1173
# 0 aligned pairs: 1175
# 0 aligned pairs: 1176
# 0 aligned pairs: 1178
# 0 aligned pairs: 1179
# 0 aligned pairs: 1180
# 0 aligned pairs: 1181
# 0 aligned pairs: 1182
# 0 aligned pairs: 1183
# 0 aligned pairs: 1185
# 0 aligned pairs: 1186
# 0 aligned pairs: 1187
# 0 aligned pairs: 1189
# 0 aligned pairs: 1190
# 0 aligned pairs: 1192
# 0 aligned pairs: 1193
# 0 aligned pairs: 1194
# 0 aligned pairs: 1195
# 0 aligned pairs: 1196
# 0 aligned pairs: 1197
# 0 aligned pairs: 1198
# 0 aligned pairs: 1201
# 0 aligned pairs: 1205
# 0 aligned pairs: 1206
# 0 aligned pairs: 1207
# 0 aligned pairs: 1208
# 0 aligned pairs: 1209
# 0 aligned pairs: 1210
# 0 aligned pairs: 1211
# 0 aligned pairs: 1212
# 0 aligned pairs: 1213
# 0 aligned pairs: 1214
# 0 aligned pairs: 1215
# 0 aligned pairs: 1217
# 0 aligned pairs: 1218
# 0 aligned pairs: 1219
# 0 aligned pairs: 1220
# 0 aligned pairs: 1222
# 0 aligned pairs: 1223
# 0 aligned pairs: 1224
# 0 aligned pairs: 1225
# 0 aligned pairs: 1226
# 0 aligned pairs: 1228
# 0 aligned pairs: 1229
# 0 aligned pairs: 1231
# 0 aligned pairs: 1232
# 0 aligned pairs: 1233
# 0 aligned pairs: 1234
# 0 aligned pairs: 1235
# 0 aligned pairs: 1236
# 0 aligned pairs: 1237
# 0 aligned pairs: 1238
# 0 aligned pairs: 1239
# 0 aligned pairs: 1242
# 0 aligned pairs: 1243
# 0 aligned pairs: 1245
# 0 aligned pairs: 1246
# 0 aligned pairs: 1247
# 0 aligned pairs: 1249
# 0 aligned pairs: 1250
# 0 aligned pairs: 1251
# 0 aligned pairs: 1252
# 0 aligned pairs: 1253
# 0 aligned pairs: 1254
# 0 aligned pairs: 1255
# 0 aligned pairs: 1256
# 0 aligned pairs: 1257
# 0 aligned pairs: 1258
# 0 aligned pairs: 1261
# 0 aligned pairs: 1262
# 0 aligned pairs: 1263
# 0 aligned pairs: 1264
# 0 aligned pairs: 1265
# 0 aligned pairs: 1266
# 0 aligned pairs: 1267
# 0 aligned pairs: 1268
# 0 aligned pairs: 1269
# 0 aligned pairs: 1272
# 0 aligned pairs: 1273
# 0 aligned pairs: 1274
# 0 aligned pairs: 1275
# 0 aligned pairs: 1276
# 0 aligned pairs: 1277
# 0 aligned pairs: 1278
# 0 aligned pairs: 1279
# 0 aligned pairs: 1281
# 0 aligned pairs: 1283
# 0 aligned pairs: 1284
# 0 aligned pairs: 1285
# 0 aligned pairs: 1287
# 0 aligned pairs: 1288
# 0 aligned pairs: 1289
# 0 aligned pairs: 1290
# 0 aligned pairs: 1291
# 0 aligned pairs: 1292
# 0 aligned pairs: 1293
# 0 aligned pairs: 1294
# 0 aligned pairs: 1295
# 0 aligned pairs: 1296
# 0 aligned pairs: 1298
# 0 aligned pairs: 1300
# 0 aligned pairs: 1301
# 0 aligned pairs: 1302
# 0 aligned pairs: 1303
# 0 aligned pairs: 1304
# 0 aligned pairs: 1305
# 0 aligned pairs: 1306
# 0 aligned pairs: 1309
# 0 aligned pairs: 1311
# 0 aligned pairs: 1315
# 0 aligned pairs: 1316
# 0 aligned pairs: 1317
# 0 aligned pairs: 1320
# 0 aligned pairs: 1321
# 0 aligned pairs: 1326
# 0 aligned pairs: 1327
# 0 aligned pairs: 1329
# 0 aligned pairs: 1330
# 0 aligned pairs: 1331
# 0 aligned pairs: 1332
# 0 aligned pairs: 1333
# 0 aligned pairs: 1335
# 0 aligned pairs: 1337
# 0 aligned pairs: 1338
# 0 aligned pairs: 1339
# 0 aligned pairs: 1340
# 0 aligned pairs: 1342
# 0 aligned pairs: 1345
# 0 aligned pairs: 1347
# 0 aligned pairs: 1348
# 0 aligned pairs: 1349
# 0 aligned pairs: 1350
# 0 aligned pairs: 1351
# 0 aligned pairs: 1352
# 0 aligned pairs: 1355
# 0 aligned pairs: 1356
# 0 aligned pairs: 1358
# 0 aligned pairs: 1359
# 0 aligned pairs: 1360
# 0 aligned pairs: 1361
# 0 aligned pairs: 1362
# 0 aligned pairs: 1363
# 0 aligned pairs: 1365
# 0 aligned pairs: 1366
# 0 aligned pairs: 1367
# 0 aligned pairs: 1368
# 0 aligned pairs: 1369
# 0 aligned pairs: 1371
# 0 aligned pairs: 1373
# 0 aligned pairs: 1375
# 0 aligned pairs: 1376
# 0 aligned pairs: 1377
# 0 aligned pairs: 1378
# 0 aligned pairs: 1379
# 0 aligned pairs: 1380
# 0 aligned pairs: 1383
# 0 aligned pairs: 1388
# 0 aligned pairs: 1389
# 0 aligned pairs: 1392
# 0 aligned pairs: 1393
# 0 aligned pairs: 1394
# 0 aligned pairs: 1396
# 0 aligned pairs: 1398
# 0 aligned pairs: 1399
# 0 aligned pairs: 1400
# 0 aligned pairs: 1401
# 0 aligned pairs: 1403
# 0 aligned pairs: 1404
# 0 aligned pairs: 1406
# 0 aligned pairs: 1408
# 0 aligned pairs: 1409
# 0 aligned pairs: 1410
# 0 aligned pairs: 1411
# 0 aligned pairs: 1412
# 0 aligned pairs: 1413
# 0 aligned pairs: 1414
# 0 aligned pairs: 1415
# 0 aligned pairs: 1417
# 0 aligned pairs: 1418
# 0 aligned pairs: 1419
# 0 aligned pairs: 1420
# 0 aligned pairs: 1421
# 0 aligned pairs: 1422
# 0 aligned pairs: 1423
# 0 aligned pairs: 1424
# 0 aligned pairs: 1426
# 0 aligned pairs: 1427
# 0 aligned pairs: 1428
# 0 aligned pairs: 1430
# 0 aligned pairs: 1431
# 0 aligned pairs: 1432
# 0 aligned pairs: 1433
# 0 aligned pairs: 1435
# 0 aligned pairs: 1437
# 0 aligned pairs: 1438
# 0 aligned pairs: 1439
# 0 aligned pairs: 1440
# 0 aligned pairs: 1441
# 0 aligned pairs: 1442
# 0 aligned pairs: 1444
# 0 aligned pairs: 1445
# 0 aligned pairs: 1446
# 0 aligned pairs: 1450
# 0 aligned pairs: 1451
# 0 aligned pairs: 1452
# 0 aligned pairs: 1453
# 0 aligned pairs: 1454
# 0 aligned pairs: 1455
# 0 aligned pairs: 1457
# 0 aligned pairs: 1458
# 0 aligned pairs: 1459
# 0 aligned pairs: 1461
# 0 aligned pairs: 1462
# 0 aligned pairs: 1463
# 0 aligned pairs: 1464
# 0 aligned pairs: 1466
# 0 aligned pairs: 1467
# 0 aligned pairs: 1468
# 0 aligned pairs: 1469
# 0 aligned pairs: 1470
# 0 aligned pairs: 1473
# 0 aligned pairs: 1474
# 0 aligned pairs: 1475
# 0 aligned pairs: 1476
# 0 aligned pairs: 1479
# 0 aligned pairs: 1480
# 0 aligned pairs: 1481
# 0 aligned pairs: 1482
# 0 aligned pairs: 1484
# 0 aligned pairs: 1485
# 0 aligned pairs: 1486
# 0 aligned pairs: 1487
# 0 aligned pairs: 1488
# 0 aligned pairs: 1489
# 0 aligned pairs: 1490
# 0 aligned pairs: 1491
# 0 aligned pairs: 1493
# 0 aligned pairs: 1496
# 0 aligned pairs: 1497
# 0 aligned pairs: 1500
# 0 aligned pairs: 1501
# 0 aligned pairs: 1502
# 0 aligned pairs: 1503
# 0 aligned pairs: 1504
# 0 aligned pairs: 1505
# 0 aligned pairs: 1506
# 0 aligned pairs: 1507
# 0 aligned pairs: 1509
# 0 aligned pairs: 1510
# 0 aligned pairs: 1511
# 0 aligned pairs: 1514
# 0 aligned pairs: 1515
# 0 aligned pairs: 1517
# 0 aligned pairs: 1518
# 0 aligned pairs: 1519
# 0 aligned pairs: 1521
# 0 aligned pairs: 1522
# 0 aligned pairs: 1523
# 0 aligned pairs: 1524
# 0 aligned pairs: 1526
# 0 aligned pairs: 1527
# 0 aligned pairs: 1529
# 0 aligned pairs: 1532
# 0 aligned pairs: 1533
# 0 aligned pairs: 1535
# 0 aligned pairs: 1536
# 0 aligned pairs: 1537
# 0 aligned pairs: 1539
# 0 aligned pairs: 1541
# 0 aligned pairs: 1542
# 0 aligned pairs: 1543
# 0 aligned pairs: 1545
# 0 aligned pairs: 1546
# 0 aligned pairs: 1550
# 0 aligned pairs: 1552
# 0 aligned pairs: 1553
# 0 aligned pairs: 1554
# 0 aligned pairs: 1555
# 0 aligned pairs: 1556
# 0 aligned pairs: 1558
# 0 aligned pairs: 1559
# 0 aligned pairs: 1560
# 0 aligned pairs: 1561
# 0 aligned pairs: 1562
# 0 aligned pairs: 1564
# 0 aligned pairs: 1565
# 0 aligned pairs: 1566
# 0 aligned pairs: 1567
# 0 aligned pairs: 1568
# 0 aligned pairs: 1569
# 0 aligned pairs: 1570
# 0 aligned pairs: 1572
# 0 aligned pairs: 1573
# 0 aligned pairs: 1574
# 0 aligned pairs: 1576
# 0 aligned pairs: 1577
# 0 aligned pairs: 1578
# 0 aligned pairs: 1579
# 0 aligned pairs: 1580
# 0 aligned pairs: 1581
# 0 aligned pairs: 1583
# 0 aligned pairs: 1584
# 0 aligned pairs: 1585
# 0 aligned pairs: 1586
# 0 aligned pairs: 1587
# 0 aligned pairs: 1588
# 0 aligned pairs: 1589
# 0 aligned pairs: 1590
# 0 aligned pairs: 1592
# 0 aligned pairs: 1593
# 0 aligned pairs: 1594
# 0 aligned pairs: 1595
# 0 aligned pairs: 1596
# 0 aligned pairs: 1598
# 0 aligned pairs: 1599
# 0 aligned pairs: 1601
# 0 aligned pairs: 1603
# 0 aligned pairs: 1604
# 0 aligned pairs: 1605
# 0 aligned pairs: 1607
# 0 aligned pairs: 1608
# 0 aligned pairs: 1609
# 0 aligned pairs: 1610
# 0 aligned pairs: 1613
# 0 aligned pairs: 1614
# 0 aligned pairs: 1615
# 0 aligned pairs: 1616
# 0 aligned pairs: 1617
# 0 aligned pairs: 1618
# 0 aligned pairs: 1621
# 0 aligned pairs: 1622
# 0 aligned pairs: 1623
# 0 aligned pairs: 1624
# 0 aligned pairs: 1625
# 0 aligned pairs: 1626
# 0 aligned pairs: 1627
# 0 aligned pairs: 1628
# 0 aligned pairs: 1629
# 0 aligned pairs: 1630
# 0 aligned pairs: 1632
# 0 aligned pairs: 1633
# 0 aligned pairs: 1634
# 0 aligned pairs: 1635
# 0 aligned pairs: 1636
# 0 aligned pairs: 1637
# 0 aligned pairs: 1638
# 0 aligned pairs: 1639
# 0 aligned pairs: 1640
# 0 aligned pairs: 1641
# 0 aligned pairs: 1642
# 0 aligned pairs: 1646
# 0 aligned pairs: 1648
# 0 aligned pairs: 1651
# 0 aligned pairs: 1652
# 0 aligned pairs: 1653
# 0 aligned pairs: 1654
# 0 aligned pairs: 1655
# 0 aligned pairs: 1656
# 0 aligned pairs: 1657
# 0 aligned pairs: 1658
# 0 aligned pairs: 1660
# 0 aligned pairs: 1661
# 0 aligned pairs: 1663
# 0 aligned pairs: 1664
# 0 aligned pairs: 1666
# 0 aligned pairs: 1667
# 0 aligned pairs: 1668
# 0 aligned pairs: 1669
# 0 aligned pairs: 1670
# 0 aligned pairs: 1671
# 0 aligned pairs: 1672
# 0 aligned pairs: 1673
# 0 aligned pairs: 1675
# 0 aligned pairs: 1677
# 0 aligned pairs: 1679
# 0 aligned pairs: 1680
# 0 aligned pairs: 1681
# 0 aligned pairs: 1682
# 0 aligned pairs: 1683
# 0 aligned pairs: 1684
# 0 aligned pairs: 1685
# 0 aligned pairs: 1686
# 0 aligned pairs: 1687
# 0 aligned pairs: 1692
# 0 aligned pairs: 1693
# 0 aligned pairs: 1695
# 0 aligned pairs: 1696
# 0 aligned pairs: 1697
# 0 aligned pairs: 1698
# 0 aligned pairs: 1699
# 0 aligned pairs: 1701
# 0 aligned pairs: 1702
# 0 aligned pairs: 1703
# 0 aligned pairs: 1705
# 0 aligned pairs: 1707
# 0 aligned pairs: 1708
# 0 aligned pairs: 1709
# 0 aligned pairs: 1710
# 0 aligned pairs: 1711
# 0 aligned pairs: 1712
# 0 aligned pairs: 1713
# 0 aligned pairs: 1714
# 0 aligned pairs: 1715
# 0 aligned pairs: 1716
# 0 aligned pairs: 1717
# 0 aligned pairs: 1718
# 0 aligned pairs: 1719
# 0 aligned pairs: 1720
# 0 aligned pairs: 1721
# 0 aligned pairs: 1722
# 0 aligned pairs: 1723
# 0 aligned pairs: 1725
# 0 aligned pairs: 1726
# 0 aligned pairs: 1728
# 0 aligned pairs: 1729
# 0 aligned pairs: 1731
# 0 aligned pairs: 1733
# 0 aligned pairs: 1734
# 0 aligned pairs: 1735
# 0 aligned pairs: 1739
# 0 aligned pairs: 1740
# 0 aligned pairs: 1741
# 0 aligned pairs: 1742
# 0 aligned pairs: 1743
# 0 aligned pairs: 1744
# 0 aligned pairs: 1745
# 0 aligned pairs: 1746
# 0 aligned pairs: 1747
# 0 aligned pairs: 1748
# 0 aligned pairs: 1750
# 0 aligned pairs: 1751
# 0 aligned pairs: 1752
# 0 aligned pairs: 1753
# 0 aligned pairs: 1754
# 0 aligned pairs: 1755
# 0 aligned pairs: 1756
# 0 aligned pairs: 1757
# 0 aligned pairs: 1758
# 0 aligned pairs: 1759
# 0 aligned pairs: 1760
# 0 aligned pairs: 1761
# 0 aligned pairs: 1762
# 0 aligned pairs: 1764
# 0 aligned pairs: 1765
# 0 aligned pairs: 1767
# 0 aligned pairs: 1771
# 0 aligned pairs: 1772
# 0 aligned pairs: 1773
# 0 aligned pairs: 1774
# 0 aligned pairs: 1775
# 0 aligned pairs: 1776
# 0 aligned pairs: 1777
# 0 aligned pairs: 1778
# 0 aligned pairs: 1781
# 0 aligned pairs: 1782
# 0 aligned pairs: 1783
# 0 aligned pairs: 1784
# 0 aligned pairs: 1785
# 0 aligned pairs: 1786
# 0 aligned pairs: 1787
# 0 aligned pairs: 1788
# 0 aligned pairs: 1789
# 0 aligned pairs: 1790
# 0 aligned pairs: 1791
# 0 aligned pairs: 1793
# 0 aligned pairs: 1794
# 0 aligned pairs: 1795
# 0 aligned pairs: 1799
# 0 aligned pairs: 1801
# 0 aligned pairs: 1802
# 0 aligned pairs: 1803
# 0 aligned pairs: 1804
# 0 aligned pairs: 1805
# 0 aligned pairs: 1806
# 0 aligned pairs: 1808
# 0 aligned pairs: 1809
# 0 aligned pairs: 1810
# 0 aligned pairs: 1811
# 0 aligned pairs: 1812
# 0 aligned pairs: 1815
# 0 aligned pairs: 1816
# 0 aligned pairs: 1817
# 0 aligned pairs: 1819
# 0 aligned pairs: 1821
# 0 aligned pairs: 1823
# 0 aligned pairs: 1825
# 0 aligned pairs: 1826
# 0 aligned pairs: 1828
# 0 aligned pairs: 1830
# 0 aligned pairs: 1831
# 0 aligned pairs: 1832
# 0 aligned pairs: 1835
# 0 aligned pairs: 1836
# 0 aligned pairs: 1837
# 0 aligned pairs: 1838
# 0 aligned pairs: 1839
# 0 aligned pairs: 1841
# 0 aligned pairs: 1842
# 0 aligned pairs: 1844
# 0 aligned pairs: 1845
# 0 aligned pairs: 1846
# 0 aligned pairs: 1848
# 0 aligned pairs: 1850
# 0 aligned pairs: 1855
# 0 aligned pairs: 1856
# 0 aligned pairs: 1857
# 0 aligned pairs: 1858
# 0 aligned pairs: 1859
# 0 aligned pairs: 1861
# 0 aligned pairs: 1862
# 0 aligned pairs: 1863
# 0 aligned pairs: 1864
# 0 aligned pairs: 1865
# 0 aligned pairs: 1866
# 0 aligned pairs: 1867
# 0 aligned pairs: 1868
# 0 aligned pairs: 1869
# 0 aligned pairs: 1870
# 0 aligned pairs: 1873
# 0 aligned pairs: 1874
# 0 aligned pairs: 1875
# 0 aligned pairs: 1876
# 0 aligned pairs: 1877
# 0 aligned pairs: 1878
# 0 aligned pairs: 1879
# 0 aligned pairs: 1880
# 0 aligned pairs: 1883
# 0 aligned pairs: 1886
# 0 aligned pairs: 1887
# 0 aligned pairs: 1888
# 0 aligned pairs: 1889
# 0 aligned pairs: 1891
# 0 aligned pairs: 1892
# 0 aligned pairs: 1893
# 0 aligned pairs: 1894
# 0 aligned pairs: 1895
# 0 aligned pairs: 1897
# 0 aligned pairs: 1898
# 0 aligned pairs: 1899
# 0 aligned pairs: 1900
# 0 aligned pairs: 1901
# 0 aligned pairs: 1902
# 0 aligned pairs: 1904
# 0 aligned pairs: 1905
# 0 aligned pairs: 1906
# 0 aligned pairs: 1907
# 0 aligned pairs: 1908
# 0 aligned pairs: 1909
# 0 aligned pairs: 1910
# 0 aligned pairs: 1911
# 0 aligned pairs: 1912
# 0 aligned pairs: 1915
# 0 aligned pairs: 1917
# 0 aligned pairs: 1918
# 0 aligned pairs: 1921
# 0 aligned pairs: 1922
# 0 aligned pairs: 1923
# 0 aligned pairs: 1924
# 0 aligned pairs: 1925
# 0 aligned pairs: 1926
# 0 aligned pairs: 1927
# 0 aligned pairs: 1929
# 0 aligned pairs: 1930
# 0 aligned pairs: 1931
# 0 aligned pairs: 1932
# 0 aligned pairs: 1933
# 0 aligned pairs: 1934
# 0 aligned pairs: 1935
# 0 aligned pairs: 1936
# 0 aligned pairs: 1937
# 0 aligned pairs: 1938
# 0 aligned pairs: 1939
# 0 aligned pairs: 1940
# 0 aligned pairs: 1941
# 0 aligned pairs: 1942
# 0 aligned pairs: 1943
# 0 aligned pairs: 1944
# 0 aligned pairs: 1945
# 0 aligned pairs: 1946
# 0 aligned pairs: 1947
# 0 aligned pairs: 1948
# 0 aligned pairs: 1949
# 0 aligned pairs: 1950
# 0 aligned pairs: 1952
# 0 aligned pairs: 1953
# 0 aligned pairs: 1954
# 0 aligned pairs: 1957
# 0 aligned pairs: 1958
# 0 aligned pairs: 1959
# 0 aligned pairs: 1960
# 0 aligned pairs: 1961
# 0 aligned pairs: 1962
# 0 aligned pairs: 1963
# 0 aligned pairs: 1964
# 0 aligned pairs: 1965
# 0 aligned pairs: 1966
# 0 aligned pairs: 1969
# 0 aligned pairs: 1971
# 0 aligned pairs: 1972
# 0 aligned pairs: 1973
# 0 aligned pairs: 1974
# 0 aligned pairs: 1975
# 0 aligned pairs: 1976
# 0 aligned pairs: 1977
# 0 aligned pairs: 1978
# 0 aligned pairs: 1979
# 0 aligned pairs: 1980
# 0 aligned pairs: 1981
# 0 aligned pairs: 1982
# 0 aligned pairs: 1984
# 0 aligned pairs: 1986
# 0 aligned pairs: 1987
# 0 aligned pairs: 1988
# 0 aligned pairs: 1989
# 0 aligned pairs: 1990
# 0 aligned pairs: 1991
# 0 aligned pairs: 1992
# 0 aligned pairs: 1993
# 0 aligned pairs: 1994
# 0 aligned pairs: 1995
# 0 aligned pairs: 1996
# 0 aligned pairs: 1997
# 0 aligned pairs: 1999
# 0 aligned pairs: 2000
# 0 aligned pairs: 2002
# 0 aligned pairs: 2003
# 0 aligned pairs: 2005
# 0 aligned pairs: 2006
# 0 aligned pairs: 2009
# 0 aligned pairs: 2011
# 0 aligned pairs: 2013
# 0 aligned pairs: 2014
# 0 aligned pairs: 2017
# 0 aligned pairs: 2018
# 0 aligned pairs: 2021
# 0 aligned pairs: 2022
# 0 aligned pairs: 2023
# 0 aligned pairs: 2024
# 0 aligned pairs: 2025
# 0 aligned pairs: 2026
# 0 aligned pairs: 2028
# 0 aligned pairs: 2029
# 0 aligned pairs: 2030
# 0 aligned pairs: 2031
# 0 aligned pairs: 2032
# 0 aligned pairs: 2033
# 0 aligned pairs: 2034
# 0 aligned pairs: 2035
# 0 aligned pairs: 2037
# 0 aligned pairs: 2038
# 0 aligned pairs: 2039
# 0 aligned pairs: 2040
# 0 aligned pairs: 2041
# 0 aligned pairs: 2042
# 0 aligned pairs: 2043
# 0 aligned pairs: 2046
# 0 aligned pairs: 2049
# 0 aligned pairs: 2050
# 0 aligned pairs: 2051
# 0 aligned pairs: 2053
# 0 aligned pairs: 2054
# 0 aligned pairs: 2055
# 0 aligned pairs: 2056
# 0 aligned pairs: 2057
# 0 aligned pairs: 2058
# 0 aligned pairs: 2060
# 0 aligned pairs: 2063
# 0 aligned pairs: 2066
# 0 aligned pairs: 2067
# 0 aligned pairs: 2068
# 0 aligned pairs: 2069
# 0 aligned pairs: 2070
# 0 aligned pairs: 2071
# 0 aligned pairs: 2072
# 0 aligned pairs: 2073
# 0 aligned pairs: 2075
# 0 aligned pairs: 2076
# 0 aligned pairs: 2077
# 0 aligned pairs: 2079
# 0 aligned pairs: 2080
# 0 aligned pairs: 2081
# 0 aligned pairs: 2082
# 0 aligned pairs: 2084
# 0 aligned pairs: 2085
# 0 aligned pairs: 2087
# 0 aligned pairs: 2088
# 0 aligned pairs: 2089
# 0 aligned pairs: 2090
# 0 aligned pairs: 2092
# 0 aligned pairs: 2094
# 0 aligned pairs: 2095
# 0 aligned pairs: 2096
# 0 aligned pairs: 2097
# 0 aligned pairs: 2098
# 0 aligned pairs: 2099
# 0 aligned pairs: 2100
# 0 aligned pairs: 2102
# 0 aligned pairs: 2103
# 0 aligned pairs: 2105
# 0 aligned pairs: 2108
# 0 aligned pairs: 2109
# 0 aligned pairs: 2110
# 0 aligned pairs: 2111
# 0 aligned pairs: 2112
# 0 aligned pairs: 2113
# 0 aligned pairs: 2115
# 0 aligned pairs: 2116
# 0 aligned pairs: 2117
# 0 aligned pairs: 2118
# 0 aligned pairs: 2120
# 0 aligned pairs: 2121
# 0 aligned pairs: 2122
# 0 aligned pairs: 2124
# 0 aligned pairs: 2125
# 0 aligned pairs: 2126
# 0 aligned pairs: 2128
# 0 aligned pairs: 2129
# 0 aligned pairs: 2131
# 0 aligned pairs: 2133
# 0 aligned pairs: 2134
# 0 aligned pairs: 2135
# 0 aligned pairs: 2136
# 0 aligned pairs: 2137
# 0 aligned pairs: 2138
# 0 aligned pairs: 2140
# 0 aligned pairs: 2142
# 0 aligned pairs: 2143
# 0 aligned pairs: 2144
# 0 aligned pairs: 2147
# 0 aligned pairs: 2148
# 0 aligned pairs: 2149
# 0 aligned pairs: 2150
# 0 aligned pairs: 2151
# 0 aligned pairs: 2152
# 0 aligned pairs: 2154
# 0 aligned pairs: 2155
# 0 aligned pairs: 2156
# 0 aligned pairs: 2157
# 0 aligned pairs: 2159
# 0 aligned pairs: 2160
# 0 aligned pairs: 2161
# 0 aligned pairs: 2162
# 0 aligned pairs: 2163
# 0 aligned pairs: 2165
# 0 aligned pairs: 2166
# 0 aligned pairs: 2167
# 0 aligned pairs: 2168
# 0 aligned pairs: 2169
# 0 aligned pairs: 2170
# 0 aligned pairs: 2174
# 0 aligned pairs: 2175
# 0 aligned pairs: 2176
# 0 aligned pairs: 2178
# 0 aligned pairs: 2180
# 0 aligned pairs: 2181
# 0 aligned pairs: 2182
# 0 aligned pairs: 2183
# 0 aligned pairs: 2184
# 0 aligned pairs: 2186
# 0 aligned pairs: 2187
# 0 aligned pairs: 2188
# 0 aligned pairs: 2189
# 0 aligned pairs: 2190
# 0 aligned pairs: 2191
# 0 aligned pairs: 2192
# 0 aligned pairs: 2193
# 0 aligned pairs: 2195
# 0 aligned pairs: 2196
# 0 aligned pairs: 2197
# 0 aligned pairs: 2198
# 0 aligned pairs: 2200
# 0 aligned pairs: 2201
# 0 aligned pairs: 2202
# 0 aligned pairs: 2204
# 0 aligned pairs: 2205
# 0 aligned pairs: 2207
# 0 aligned pairs: 2208
# 0 aligned pairs: 2209
# 0 aligned pairs: 2210
# 0 aligned pairs: 2211
# 0 aligned pairs: 2213
# 0 aligned pairs: 2214
# 0 aligned pairs: 2215
# 0 aligned pairs: 2216
# 0 aligned pairs: 2218
# 0 aligned pairs: 2219
# 0 aligned pairs: 2220
# 0 aligned pairs: 2221
# 0 aligned pairs: 2222
# 0 aligned pairs: 2224
# 0 aligned pairs: 2225
# 0 aligned pairs: 2226
# 0 aligned pairs: 2227
# 0 aligned pairs: 2228
# 0 aligned pairs: 2229
# 0 aligned pairs: 2233
# 0 aligned pairs: 2235
# 0 aligned pairs: 2236
# 0 aligned pairs: 2238
# 0 aligned pairs: 2239
# 0 aligned pairs: 2241
# 0 aligned pairs: 2243
# 0 aligned pairs: 2245
# 0 aligned pairs: 2246
# 0 aligned pairs: 2248
# 0 aligned pairs: 2249
# 0 aligned pairs: 2250
# 0 aligned pairs: 2251
# 0 aligned pairs: 2252
# 0 aligned pairs: 2253
# 0 aligned pairs: 2254
# 0 aligned pairs: 2255
# 0 aligned pairs: 2256
# 0 aligned pairs: 2258
# 0 aligned pairs: 2259
# 0 aligned pairs: 2260
# 0 aligned pairs: 2261
# 0 aligned pairs: 2262
# 0 aligned pairs: 2264
# 0 aligned pairs: 2265
# 0 aligned pairs: 2267
# 0 aligned pairs: 2268
# 0 aligned pairs: 2269
# 0 aligned pairs: 2270
# 0 aligned pairs: 2271
# 0 aligned pairs: 2274
# 0 aligned pairs: 2275
# 0 aligned pairs: 2276
# 0 aligned pairs: 2278
# 0 aligned pairs: 2279
# 0 aligned pairs: 2280
# 0 aligned pairs: 2281
# 0 aligned pairs: 2283
# 0 aligned pairs: 2284
# 0 aligned pairs: 2286
# 0 aligned pairs: 2287
# 0 aligned pairs: 2288
# 0 aligned pairs: 2289
# 0 aligned pairs: 2290
# 0 aligned pairs: 2291
# 0 aligned pairs: 2292
# 0 aligned pairs: 2293
# 0 aligned pairs: 2294
# 0 aligned pairs: 2295
# 0 aligned pairs: 2296
# 0 aligned pairs: 2297
# 0 aligned pairs: 2298
# 0 aligned pairs: 2299
# 0 aligned pairs: 2300
# 0 aligned pairs: 2301
# 0 aligned pairs: 2303
# 0 aligned pairs: 2305
# 0 aligned pairs: 2310
# 0 aligned pairs: 2312
# 0 aligned pairs: 2313
# 0 aligned pairs: 2314
# 0 aligned pairs: 2315
# 0 aligned pairs: 2316
# 0 aligned pairs: 2317
# 0 aligned pairs: 2318
# 0 aligned pairs: 2320
# 0 aligned pairs: 2321
# 0 aligned pairs: 2323
# 0 aligned pairs: 2327
# 0 aligned pairs: 2328
# 0 aligned pairs: 2329
# 0 aligned pairs: 2330
# 0 aligned pairs: 2331
# 0 aligned pairs: 2333
# 0 aligned pairs: 2334
# 0 aligned pairs: 2335
# 0 aligned pairs: 2337
# 0 aligned pairs: 2338
# 0 aligned pairs: 2340
# 0 aligned pairs: 2341
# 0 aligned pairs: 2342
# 0 aligned pairs: 2344
# 0 aligned pairs: 2345
# 0 aligned pairs: 2346
# 0 aligned pairs: 2347
# 0 aligned pairs: 2348
# 0 aligned pairs: 2350
# 0 aligned pairs: 2351
# 0 aligned pairs: 2352
# 0 aligned pairs: 2353
# 0 aligned pairs: 2354
# 0 aligned pairs: 2355
# 0 aligned pairs: 2357
# 0 aligned pairs: 2358
# 0 aligned pairs: 2359
# 0 aligned pairs: 2360
# 0 aligned pairs: 2361
# 0 aligned pairs: 2362
# 0 aligned pairs: 2366
# 0 aligned pairs: 2367
# 0 aligned pairs: 2368
# 0 aligned pairs: 2369
# 0 aligned pairs: 2371
# 0 aligned pairs: 2372
# 0 aligned pairs: 2373
# 0 aligned pairs: 2374
# 0 aligned pairs: 2376
# 0 aligned pairs: 2378
# 0 aligned pairs: 2379
# 0 aligned pairs: 2380
# 0 aligned pairs: 2382
# 0 aligned pairs: 2383
# 0 aligned pairs: 2384
# 0 aligned pairs: 2385
# 0 aligned pairs: 2387
# 0 aligned pairs: 2388
# 0 aligned pairs: 2389
# 0 aligned pairs: 2390
# 0 aligned pairs: 2391
# 0 aligned pairs: 2392
# 0 aligned pairs: 2393
# 0 aligned pairs: 2394
# 0 aligned pairs: 2395
# 0 aligned pairs: 2396
# 0 aligned pairs: 2397
# 0 aligned pairs: 2398
# 0 aligned pairs: 2400
# 0 aligned pairs: 2402
# 0 aligned pairs: 2403
# 0 aligned pairs: 2404
# 0 aligned pairs: 2405
# 0 aligned pairs: 2406
# 0 aligned pairs: 2407
# 0 aligned pairs: 2408
# 0 aligned pairs: 2411
# 0 aligned pairs: 2412
# 0 aligned pairs: 2415
# 0 aligned pairs: 2416
# 0 aligned pairs: 2418
# 0 aligned pairs: 2419
# 0 aligned pairs: 2420
# 0 aligned pairs: 2421
# 0 aligned pairs: 2422
# 0 aligned pairs: 2423
# 0 aligned pairs: 2424
# 0 aligned pairs: 2425
# 0 aligned pairs: 2426
# 0 aligned pairs: 2427
# 0 aligned pairs: 2428
# 0 aligned pairs: 2430
# 0 aligned pairs: 2432
# 0 aligned pairs: 2433
# 0 aligned pairs: 2434
# 0 aligned pairs: 2436
# 0 aligned pairs: 2437
# 0 aligned pairs: 2438
# 0 aligned pairs: 2439
# 0 aligned pairs: 2442
# 0 aligned pairs: 2443
# 0 aligned pairs: 2444
# 0 aligned pairs: 2446
# 0 aligned pairs: 2447
# 0 aligned pairs: 2448
# 0 aligned pairs: 2450
# 0 aligned pairs: 2451
# 0 aligned pairs: 2452
# 0 aligned pairs: 2453
# 0 aligned pairs: 2454
# 0 aligned pairs: 2455
# 0 aligned pairs: 2456
# 0 aligned pairs: 2459
# 0 aligned pairs: 2460
# 0 aligned pairs: 2461
# 0 aligned pairs: 2462
# 0 aligned pairs: 2463
# 0 aligned pairs: 2464
# 0 aligned pairs: 2465
# 0 aligned pairs: 2467
# 0 aligned pairs: 2468
# 0 aligned pairs: 2469
# 0 aligned pairs: 2470
# 0 aligned pairs: 2471
# 0 aligned pairs: 2473
# 0 aligned pairs: 2476
# 0 aligned pairs: 2477
# 0 aligned pairs: 2478
# 0 aligned pairs: 2479
# 0 aligned pairs: 2480
# 0 aligned pairs: 2482
# 0 aligned pairs: 2483
# 0 aligned pairs: 2485
# 0 aligned pairs: 2486
# 0 aligned pairs: 2487
# 0 aligned pairs: 2488
# 0 aligned pairs: 2490
# 0 aligned pairs: 2492
# 0 aligned pairs: 2493
# 0 aligned pairs: 2494
# 0 aligned pairs: 2495
# 0 aligned pairs: 2496
# 0 aligned pairs: 2497
# 0 aligned pairs: 2498
# 0 aligned pairs: 2499
# 0 aligned pairs: 2500
# 0 aligned pairs: 2501
# 0 aligned pairs: 2504
# 0 aligned pairs: 2506
# 0 aligned pairs: 2507
# 0 aligned pairs: 2508
# 0 aligned pairs: 2511
# 0 aligned pairs: 2512
# 0 aligned pairs: 2514
# 0 aligned pairs: 2516
# 0 aligned pairs: 2517
# 0 aligned pairs: 2519
# 0 aligned pairs: 2520
# 0 aligned pairs: 2521
# 0 aligned pairs: 2522
# 0 aligned pairs: 2523
# 0 aligned pairs: 2524
# 0 aligned pairs: 2525
# 0 aligned pairs: 2526
# 0 aligned pairs: 2527
# 0 aligned pairs: 2528
# 0 aligned pairs: 2530
# 0 aligned pairs: 2532
# 0 aligned pairs: 2533
# 0 aligned pairs: 2534
# 0 aligned pairs: 2535
# 0 aligned pairs: 2536
# 0 aligned pairs: 2537
# 0 aligned pairs: 2538
# 0 aligned pairs: 2540
# 0 aligned pairs: 2541
# 0 aligned pairs: 2542
# 0 aligned pairs: 2543
# 0 aligned pairs: 2544
# 0 aligned pairs: 2546
# 0 aligned pairs: 2547
# 0 aligned pairs: 2548
# 0 aligned pairs: 2549
# 0 aligned pairs: 2551
# 0 aligned pairs: 2553
# 0 aligned pairs: 2554
# 0 aligned pairs: 2556
# 0 aligned pairs: 2557
# 0 aligned pairs: 2558
# 0 aligned pairs: 2559
# 0 aligned pairs: 2560
# 0 aligned pairs: 2562
# 0 aligned pairs: 2563
# 0 aligned pairs: 2564
# 0 aligned pairs: 2565
# 0 aligned pairs: 2566
# 0 aligned pairs: 2567
# 0 aligned pairs: 2568
# 0 aligned pairs: 2569
# 0 aligned pairs: 2570
# 0 aligned pairs: 2571
# 0 aligned pairs: 2572
# 0 aligned pairs: 2573
# 0 aligned pairs: 2574
# 0 aligned pairs: 2576
# 0 aligned pairs: 2577
# 0 aligned pairs: 2578
# 0 aligned pairs: 2579
# 0 aligned pairs: 2580
# 0 aligned pairs: 2581
# 0 aligned pairs: 2582
# 0 aligned pairs: 2583
# 0 aligned pairs: 2584
# 0 aligned pairs: 2585
# 0 aligned pairs: 2586
# 0 aligned pairs: 2587
# 0 aligned pairs: 2588
# 0 aligned pairs: 2590
# 0 aligned pairs: 2591
# 0 aligned pairs: 2592
# 0 aligned pairs: 2593
# 0 aligned pairs: 2596
# 0 aligned pairs: 2597
# 0 aligned pairs: 2598
# 0 aligned pairs: 2599
# 0 aligned pairs: 2600
# 0 aligned pairs: 2601
# 0 aligned pairs: 2602
# 0 aligned pairs: 2603
# 0 aligned pairs: 2606
# 0 aligned pairs: 2607
# 0 aligned pairs: 2609
# 0 aligned pairs: 2610
# 0 aligned pairs: 2611
# 0 aligned pairs: 2612
# 0 aligned pairs: 2613
# 0 aligned pairs: 2614
# 0 aligned pairs: 2617
# 0 aligned pairs: 2618
# 0 aligned pairs: 2619
# 0 aligned pairs: 2620
# 0 aligned pairs: 2621
# 0 aligned pairs: 2622
# 0 aligned pairs: 2623
# 0 aligned pairs: 2625
# 0 aligned pairs: 2626
# 0 aligned pairs: 2627
# 0 aligned pairs: 2629
# 0 aligned pairs: 2632
# 0 aligned pairs: 2633
# 0 aligned pairs: 2634
# 0 aligned pairs: 2636
# 0 aligned pairs: 2637
# 0 aligned pairs: 2638
# 0 aligned pairs: 2639
# 0 aligned pairs: 2640
# 0 aligned pairs: 2641
# 0 aligned pairs: 2642
# 0 aligned pairs: 2643
# 0 aligned pairs: 2644
# 0 aligned pairs: 2645
# 0 aligned pairs: 2649
# 0 aligned pairs: 2650
# 0 aligned pairs: 2651
# 0 aligned pairs: 2652
# 0 aligned pairs: 2653
# 0 aligned pairs: 2654
# 0 aligned pairs: 2655
# 0 aligned pairs: 2656
# 0 aligned pairs: 2657
# 0 aligned pairs: 2661
# 0 aligned pairs: 2664
# 0 aligned pairs: 2665
# 0 aligned pairs: 2666
# 0 aligned pairs: 2667
# 0 aligned pairs: 2669
# 0 aligned pairs: 2670
# 0 aligned pairs: 2671
# 0 aligned pairs: 2672
# 0 aligned pairs: 2673
# 0 aligned pairs: 2676
# 0 aligned pairs: 2677
# 0 aligned pairs: 2679
# 0 aligned pairs: 2680
# 0 aligned pairs: 2682
# 0 aligned pairs: 2683
# 0 aligned pairs: 2684
# 0 aligned pairs: 2685
# 0 aligned pairs: 2687
# 0 aligned pairs: 2688
# 0 aligned pairs: 2689
# 0 aligned pairs: 2693
# 0 aligned pairs: 2694
# 0 aligned pairs: 2695
# 0 aligned pairs: 2696
# 0 aligned pairs: 2697
# 0 aligned pairs: 2698
# 0 aligned pairs: 2700
# 0 aligned pairs: 2702
# 0 aligned pairs: 2703
# 0 aligned pairs: 2704
# 0 aligned pairs: 2705
# 0 aligned pairs: 2706
# 0 aligned pairs: 2707
# 0 aligned pairs: 2708
# 0 aligned pairs: 2709
# 0 aligned pairs: 2710
# 0 aligned pairs: 2711
# 0 aligned pairs: 2713
# 0 aligned pairs: 2715
# 0 aligned pairs: 2716
# 0 aligned pairs: 2718
# 0 aligned pairs: 2719
# 0 aligned pairs: 2720
# 0 aligned pairs: 2721
# 0 aligned pairs: 2722
# 0 aligned pairs: 2723
# 0 aligned pairs: 2725
# 0 aligned pairs: 2726
# 0 aligned pairs: 2729
# 0 aligned pairs: 2732
# 0 aligned pairs: 2733
# 0 aligned pairs: 2734
# 0 aligned pairs: 2735
# 0 aligned pairs: 2736
# 0 aligned pairs: 2737
# 0 aligned pairs: 2738
# 0 aligned pairs: 2742
# 0 aligned pairs: 2743
# 0 aligned pairs: 2749
# 0 aligned pairs: 2750
# 0 aligned pairs: 2753
# 0 aligned pairs: 2754
# 0 aligned pairs: 2755
# 0 aligned pairs: 2756
# 0 aligned pairs: 2758
# 0 aligned pairs: 2759
# 0 aligned pairs: 2760
# 0 aligned pairs: 2761
# 0 aligned pairs: 2763
# 0 aligned pairs: 2764
# 0 aligned pairs: 2767
# 0 aligned pairs: 2768
# 0 aligned pairs: 2769
# 0 aligned pairs: 2771
# 0 aligned pairs: 2772
# 0 aligned pairs: 2773
# 0 aligned pairs: 2775
# 0 aligned pairs: 2776
# 0 aligned pairs: 2777
# 0 aligned pairs: 2778
# 0 aligned pairs: 2779
# 0 aligned pairs: 2780
# 0 aligned pairs: 2781
# 0 aligned pairs: 2783
# 0 aligned pairs: 2784
# 0 aligned pairs: 2785
# 0 aligned pairs: 2786
# 0 aligned pairs: 2787
# 0 aligned pairs: 2788
# 0 aligned pairs: 2789
# 0 aligned pairs: 2790
# 0 aligned pairs: 2791
# 0 aligned pairs: 2792
# 0 aligned pairs: 2793
# 0 aligned pairs: 2794
# 0 aligned pairs: 2795
# 0 aligned pairs: 2796
# 0 aligned pairs: 2798
# 0 aligned pairs: 2802
# 0 aligned pairs: 2803
# 0 aligned pairs: 2805
# 0 aligned pairs: 2806
# 0 aligned pairs: 2808
# 0 aligned pairs: 2809
# 0 aligned pairs: 2810
# 0 aligned pairs: 2811
# 0 aligned pairs: 2812
# 0 aligned pairs: 2813
# 0 aligned pairs: 2814
# 0 aligned pairs: 2815
# 0 aligned pairs: 2817
# 0 aligned pairs: 2818
# 0 aligned pairs: 2819
# 0 aligned pairs: 2820
# 0 aligned pairs: 2821
# 0 aligned pairs: 2822
# 0 aligned pairs: 2823
# 0 aligned pairs: 2825
# 0 aligned pairs: 2827
# 0 aligned pairs: 2832
# 0 aligned pairs: 2833
# 0 aligned pairs: 2836
# 0 aligned pairs: 2838
# 0 aligned pairs: 2840
# 0 aligned pairs: 2842
# 0 aligned pairs: 2843
# 0 aligned pairs: 2844
# 0 aligned pairs: 2845
# 0 aligned pairs: 2846
# 0 aligned pairs: 2847
# 0 aligned pairs: 2848
# 0 aligned pairs: 2849
# 0 aligned pairs: 2851
# 0 aligned pairs: 2852
# 0 aligned pairs: 2853
# 0 aligned pairs: 2855
# 0 aligned pairs: 2858
# 0 aligned pairs: 2860
# 0 aligned pairs: 2861
# 0 aligned pairs: 2863
# 0 aligned pairs: 2866
# 0 aligned pairs: 2868
# 0 aligned pairs: 2870
# 0 aligned pairs: 2872
# 0 aligned pairs: 2873
# 0 aligned pairs: 2877
# 0 aligned pairs: 2878
# 0 aligned pairs: 2880
# 0 aligned pairs: 2881
# 0 aligned pairs: 2882
# 0 aligned pairs: 2885
# 0 aligned pairs: 2890
# 0 aligned pairs: 2891
# 0 aligned pairs: 2893
# 0 aligned pairs: 2894
# 0 aligned pairs: 2895
# 0 aligned pairs: 2896
# 0 aligned pairs: 2897
# 0 aligned pairs: 2898
# 0 aligned pairs: 2901
# 0 aligned pairs: 2902
# 0 aligned pairs: 2904
# 0 aligned pairs: 2905
# 0 aligned pairs: 2906
# 0 aligned pairs: 2909
# 0 aligned pairs: 2910
# 0 aligned pairs: 2913
# 0 aligned pairs: 2914
# 0 aligned pairs: 2915
# 0 aligned pairs: 2916
# 0 aligned pairs: 2917
# 0 aligned pairs: 2918
# 0 aligned pairs: 2920
# 0 aligned pairs: 2923
# 0 aligned pairs: 2924
# 0 aligned pairs: 2925
# 0 aligned pairs: 2926
# 0 aligned pairs: 2927
# 0 aligned pairs: 2928
# 0 aligned pairs: 2929
# 0 aligned pairs: 2930
# 0 aligned pairs: 2931
# 0 aligned pairs: 2932
# 0 aligned pairs: 2933
# 0 aligned pairs: 2934
# 0 aligned pairs: 2935
# 0 aligned pairs: 2937
# 0 aligned pairs: 2939
# 0 aligned pairs: 2940
# 0 aligned pairs: 2941
# 0 aligned pairs: 2942
# 0 aligned pairs: 2943
# 0 aligned pairs: 2945
# 0 aligned pairs: 2946
# 0 aligned pairs: 2947
# 0 aligned pairs: 2948
# 0 aligned pairs: 2949
# 0 aligned pairs: 2951
# 0 aligned pairs: 2952
# 0 aligned pairs: 2954
# 0 aligned pairs: 2955
# 0 aligned pairs: 2956
# 0 aligned pairs: 2957
# 0 aligned pairs: 2958
# 0 aligned pairs: 2962
# 0 aligned pairs: 2963
# 0 aligned pairs: 2964
# 0 aligned pairs: 2965
# 0 aligned pairs: 2968
# 0 aligned pairs: 2969
# 0 aligned pairs: 2970
# 0 aligned pairs: 2971
# 0 aligned pairs: 2973
# 0 aligned pairs: 2974
# 0 aligned pairs: 2976
# 0 aligned pairs: 2977
# 0 aligned pairs: 2978
# 0 aligned pairs: 2980
# 0 aligned pairs: 2981
# 0 aligned pairs: 2982
# 0 aligned pairs: 2983
# 0 aligned pairs: 2984
# 0 aligned pairs: 2985
# 0 aligned pairs: 2986
# 0 aligned pairs: 2987
# 0 aligned pairs: 2989
# 0 aligned pairs: 2992
# 0 aligned pairs: 2993
# 0 aligned pairs: 2994
# 0 aligned pairs: 2995
# 0 aligned pairs: 2996
# 0 aligned pairs: 2997
# 0 aligned pairs: 2998
# 0 aligned pairs: 2999
# 0 aligned pairs: 3000
# 0 aligned pairs: 3002
# 0 aligned pairs: 3004
# 0 aligned pairs: 3005
# 0 aligned pairs: 3007
# 0 aligned pairs: 3008
# 0 aligned pairs: 3010
# 0 aligned pairs: 3011
# 0 aligned pairs: 3012
# 0 aligned pairs: 3014
# 0 aligned pairs: 3017
# 0 aligned pairs: 3019
# 0 aligned pairs: 3020
# 0 aligned pairs: 3021
# 0 aligned pairs: 3022
# 0 aligned pairs: 3025
# 0 aligned pairs: 3026
# 0 aligned pairs: 3029
# 0 aligned pairs: 3030
# 0 aligned pairs: 3031
# 0 aligned pairs: 3032
# 0 aligned pairs: 3033
# 0 aligned pairs: 3034
# 0 aligned pairs: 3035
# 0 aligned pairs: 3036
# 0 aligned pairs: 3037
# 0 aligned pairs: 3038
# 0 aligned pairs: 3039
# 0 aligned pairs: 3040
# 0 aligned pairs: 3042
# 0 aligned pairs: 3043
# 0 aligned pairs: 3044
# 0 aligned pairs: 3045
# 0 aligned pairs: 3046
# 0 aligned pairs: 3047
# 0 aligned pairs: 3048
# 0 aligned pairs: 3049
# 0 aligned pairs: 3050
# 0 aligned pairs: 3051
# 0 aligned pairs: 3052
# 0 aligned pairs: 3053
# 0 aligned pairs: 3054
# 0 aligned pairs: 3055
# 0 aligned pairs: 3057
# 0 aligned pairs: 3058
# 0 aligned pairs: 3059
# 0 aligned pairs: 3060
# 0 aligned pairs: 3061
# 0 aligned pairs: 3062
# 0 aligned pairs: 3063
# 0 aligned pairs: 3065
# 0 aligned pairs: 3066
# 0 aligned pairs: 3067
# 0 aligned pairs: 3069
# 0 aligned pairs: 3070
# 0 aligned pairs: 3071
# 0 aligned pairs: 3072
# 0 aligned pairs: 3073
# 0 aligned pairs: 3074
# 0 aligned pairs: 3075
# 0 aligned pairs: 3076
# 0 aligned pairs: 3077
# 0 aligned pairs: 3078
# 0 aligned pairs: 3079
# 0 aligned pairs: 3080
# 0 aligned pairs: 3081
# 0 aligned pairs: 3082
# 0 aligned pairs: 3083
# 0 aligned pairs: 3084
# 0 aligned pairs: 3085
# 0 aligned pairs: 3087
# 0 aligned pairs: 3088
# 0 aligned pairs: 3090
# 0 aligned pairs: 3091
# 0 aligned pairs: 3092
# 0 aligned pairs: 3093
# 0 aligned pairs: 3094
# 0 aligned pairs: 3095
# 0 aligned pairs: 3096
# 0 aligned pairs: 3097
# 0 aligned pairs: 3098
# 0 aligned pairs: 3100
# 0 aligned pairs: 3101
# 0 aligned pairs: 3102
# 0 aligned pairs: 3103
# 0 aligned pairs: 3104
# 0 aligned pairs: 3105
# 0 aligned pairs: 3107
# 0 aligned pairs: 3108
# 0 aligned pairs: 3109
# 0 aligned pairs: 3110
# 0 aligned pairs: 3113
# 0 aligned pairs: 3114
# 0 aligned pairs: 3115
# 0 aligned pairs: 3116
# 0 aligned pairs: 3118
# 0 aligned pairs: 3119
# 0 aligned pairs: 3120
# 0 aligned pairs: 3121
# 0 aligned pairs: 3123
# 0 aligned pairs: 3124
# 0 aligned pairs: 3125
# 0 aligned pairs: 3126
# 0 aligned pairs: 3127
# 0 aligned pairs: 3128
# 0 aligned pairs: 3129
# 0 aligned pairs: 3130
# 0 aligned pairs: 3131
# 0 aligned pairs: 3135
# 0 aligned pairs: 3136
# 0 aligned pairs: 3137
# 0 aligned pairs: 3138
# 0 aligned pairs: 3140
# 0 aligned pairs: 3141
# 0 aligned pairs: 3142
# 0 aligned pairs: 3143
# 0 aligned pairs: 3144
# 0 aligned pairs: 3146
# 0 aligned pairs: 3148
# 0 aligned pairs: 3150
# 0 aligned pairs: 3151
# 0 aligned pairs: 3153
# 0 aligned pairs: 3154
# 0 aligned pairs: 3155
# 0 aligned pairs: 3156
# 0 aligned pairs: 3157
# 0 aligned pairs: 3158
# 0 aligned pairs: 3160
# 0 aligned pairs: 3161
# 0 aligned pairs: 3162

# %% [markdown]
# # Save all parallel pairs

# %%
data = []
for mdf, ru in all_aligned_pairs:
    cleaned_mdf = clean_text(mdf)
    cleaned_ru = clean_text(ru)

    if not is_text_valid(cleaned_mdf) or not is_text_valid(cleaned_ru):
        continue

    data.append({'mdf': cleaned_mdf, 'ru': cleaned_ru})

# %%
len(data)
# Out:
# 1400

# %%
with open(DATA_PATH_PREFIX + 'aligned_wikipedia_sents_09_02.json', "w") as file:
    json.dump(data, file, ensure_ascii=False, indent=4)
